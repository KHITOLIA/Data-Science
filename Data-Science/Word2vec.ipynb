# %%
import gensim

# %%
from gensim import models

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('C:/Users/bhatt/Downloads/GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
result = model.most_similar(positive=['king', 'woman'], negative=['man'], topn=3)

# %%
# https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit?resourcekey=0-wjGZdNAUop6WykTtMip30g

# %%
result
# Out:
# [('queen', 0.7118193507194519),
#  ('monarch', 0.6189674139022827),
#  ('princess', 0.5902431011199951)]

# %%
print(model.most_similar('Car', topn=3))
# Out:
# [('car', 0.6677608489990234), ('Auto', 0.6563326716423035), ('Vehicle', 0.6293455362319946)]

# %%
print(len(model['Car']))
# Out:
# 300

# %%
print(model.most_similar('Human'))
# Out:
# [('human', 0.5524994134902954), ('Singer_Joanne_Catherall', 0.4671133756637573), ('Sexual', 0.4630460739135742), ('Animal', 0.4488033354282379), ('Protection_Programs_AAHRPP', 0.4418451189994812), ('Reproductive', 0.4382147192955017), ('Computer_Interaction_HCI', 0.43567079305648804), ('Watch_HRW', 0.43207818269729614), ('Virtual_Physiological', 0.43200552463531494), ('human_rights', 0.43150100111961365)]

# %%
print(model.most_similar('PHP'))
# Out:
# [('ASP.NET', 0.7275794744491577), ('scripting_languages', 0.7123508453369141), ('PHP5', 0.7062194347381592), ('Joomla', 0.700035572052002), ('ASP.Net', 0.6955472826957703), ('PHP_MySQL', 0.6919426918029785), ('Zend_Framework', 0.6905215978622437), ('scripting_language', 0.6846042275428772), ('Visual_Basic', 0.6807329654693604), ('J2EE', 0.6805503368377686)]

# %%
print(model['Python'])
# Out:
# [ 1.63085938e-01 -2.04101562e-01 -2.20947266e-02  7.95898438e-02
#  -2.01171875e-01 -3.75366211e-03  1.49414062e-01  3.24218750e-01
#   1.36718750e-01  2.96875000e-01  8.10546875e-02 -7.12890625e-02
#   2.16064453e-02 -3.49121094e-02 -1.48437500e-01 -2.51953125e-01
#   1.58203125e-01  2.63671875e-01 -5.07812500e-01 -3.12500000e-01
#  -8.20312500e-02  9.13085938e-02  2.30468750e-01  3.57421875e-01
#  -3.61633301e-03 -2.26562500e-01 -1.03515625e-01  4.16015625e-01
#  -1.30004883e-02 -2.79296875e-01 -7.76367188e-02  7.76367188e-02
#  -3.32031250e-01 -1.28906250e-01  1.01562500e-01  3.12500000e-02
#   1.56250000e-01  1.51367188e-01 -6.93359375e-02  2.19726562e-01
#   5.50781250e-01 -4.51660156e-02  1.70898438e-01  6.17187500e-01
#  -1.84570312e-01 -8.59375000e-02 -5.02929688e-02 -2.30468750e-01
#   3.58886719e-02  3.08593750e-01 -3.90625000e-01 -4.76562500e-01
#   5.05371094e-02  9.22851562e-02  6.93359375e-02  2.06054688e-01
# ...

# %%
model['Hello']
# Out:
# array([-0.05102539,  0.12060547, -0.01257324,  0.03088379, -0.08544922,
#         0.0534668 , -0.13964844, -0.16308594,  0.08300781,  0.20507812,
#        -0.09423828,  0.15527344, -0.00418091,  0.02111816, -0.10986328,
#         0.22460938,  0.22265625,  0.15917969,  0.05786133, -0.15527344,
#         0.23046875,  0.34765625,  0.44335938, -0.14550781,  0.15136719,
#         0.02209473, -0.16308594,  0.2578125 ,  0.20019531,  0.06054688,
#        -0.0222168 , -0.13183594, -0.06396484, -0.12792969,  0.09814453,
#        -0.13574219,  0.01928711,  0.25195312,  0.14257812,  0.2421875 ,
#         0.03173828, -0.17089844,  0.26171875,  0.4296875 ,  0.24804688,
#        -0.10351562, -0.13867188, -0.14257812, -0.20703125, -0.00860596,
#        -0.43359375, -0.01757812,  0.40234375,  0.32617188,  0.33203125,
#         0.01000977, -0.11523438, -0.12695312,  0.01940918, -0.25390625,
#         0.00393677, -0.00344849, -0.19042969,  0.05419922,  0.14453125,
# ...
