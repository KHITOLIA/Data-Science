# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np

# %%
model_resnet = ResNet50()

# %%
model_resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %%
image_path = 'C:/Users/bhatt/OneDrive/Desktop/whisper-main/download.jpeg'

# %%
img = image.load_img(image_path, target_size=(224, 224))

# %%
plt.imshow(img)
plt.show()

# %%
img = image.img_to_array(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img = np.expand_dims(img, axis = 0)

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
pred = model_resnet.predict(img)
# Out:
# 1/1 [==============================] - 0s 110ms/step

# %%
np.argmax(pred)
# Out:
# 225

# %%
tf.keras.applications.resnet50.decode_predictions(pred)[0]
# Out:
# [('n02105162', 'malinois', 0.7802345),
#  ('n02097209', 'standard_schnauzer', 0.101361215),
#  ('n02106662', 'German_shepherd', 0.030358871),
#  ('n02105412', 'kelpie', 0.024791993),
#  ('n02091467', 'Norwegian_elkhound', 0.019748379)]

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
img = preprocess_input(img)

# %%
pred = model_resnet.predict(img)
# Out:
# 1/1 [==============================] - 0s 124ms/step

# %%
np.argmax(pred)
# Out:
# 235

# %%
tf.keras.applications.resnet50.decode_predictions(pred)[0]
# Out:
# [('n02106662', 'German_shepherd', 0.98537725),
#  ('n02105162', 'malinois', 0.011365237),
#  ('n02105251', 'briard', 0.0010203645),
#  ('n02105412', 'kelpie', 0.00040862383),
#  ('n02111129', 'Leonberg', 0.0003299579)]

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
img = img.reshape((224, 224, 3))

# %%
plt.imshow(img)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
