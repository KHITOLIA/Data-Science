# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Bike_Sales_Prepare_Lab_3.4.7.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0           0         261695  2021-12-01  1.0  December  2021            39
# 1           1         261695  2021-12-01  1.0  December  2021            44
# 2           2         261697  2021-12-02  2.0  December  2021            37
# 3           3         261698  2021-12-02  2.0  December  2021            31
# 4           4         261699  2021-12-03  3.0  December  2021            37
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
# ...

# %%
df.to_csv('Bike_Sales_Prepare_Lab_3.4.7.xlsx', index= True)

# %%
df.head()
# Out:
#    Unnamed: 0  Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0           0         261695  2021-12-01  1.0  December  2021            39
# 1           1         261695  2021-12-01  1.0  December  2021            44
# 2           2         261697  2021-12-02  2.0  December  2021            37
# 3           3         261698  2021-12-02  2.0  December  2021            31
# 4           4         261699  2021-12-03  3.0  December  2021            37
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
# ...

# %%
df.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#     Sales_Order #        Date   Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01   1.0  December  2021            39
# 1          261695  2021-12-01   1.0  December  2021            44
# 2          261697  2021-12-02   2.0  December  2021            37
# 3          261698  2021-12-02   2.0  December  2021            31
# 4          261699  2021-12-03   3.0  December  2021            37
# ..            ...         ...   ...       ...   ...           ...
# 84         261778  2021-12-22  22.0  December  2021            41
# 85         261779  2021-12-23  23.0  December  2021            30
# 86         261780  2021-12-23  23.0  December  2021            31
# 87         261781  2021-12-23  23.0  December  2021            35
# 88         261782  2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
duplicate = df.duplicated()
print(duplicate)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Length: 89, dtype: bool

# %%
in_columns = df.duplicated(subset=['State'])
print(in_columns)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
#       ...
# 84     True
# 85     True
# 86     True
# 87     True
# 88     True
# Length: 89, dtype: bool

# %%
num_duplicate = df.duplicated().sum()
print(num_duplicate)
# Out:
# 0

# %%
duplicate_rows = df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Sales_Order #, Date, Day, Month, Year, Customer_Age, Age_Group, Customer_Gender, Country, State, Product_Category, Sub_Category, Product_Description, Order_Quantity,  Unit_Cost ,  Unit_Price ,  Profit ,  Cost , Revenue]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Sales_Order #          0
# Date                   0
# Day                    1
# Month                  0
# Year                   0
# Customer_Age           0
# Age_Group              1
# Customer_Gender        0
# Country                0
# State                  0
# Product_Category       0
# Sub_Category           0
# Product_Description    1
# Order_Quantity         1
#  Unit_Cost             0
#  Unit_Price            0
#  Profit                0
#  Cost                  0
# Revenue                0
# dtype: int64

# %%
# Out:
#    Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0         261695  2021-12-01  1.0  December  2021            39
# 1         261695  2021-12-01  1.0  December  2021            44
# 2         261697  2021-12-02  2.0  December  2021            37
# 3         261698  2021-12-02  2.0  December  2021            31
# 4         261699  2021-12-03  3.0  December  2021            37
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
#   Product_Category    Sub_Category        Product_Description  Order_Quantity  \
# ...

# %%
(df['Country'].str.split(' ')[0][0])
# Out:
# 'United'

# %%
df['Country'].str.strip()
# Out:
# 0      United States
# 1     United Kingdom
# 2      United States
# 3          Australia
# 4     United  States
#            ...
# 84           Germany
# 85     United States
# 86            Canada
# 87     United States
# 88         Australia
# Name: Country, Length: 89, dtype: object

# %%
df['Country'].str.contains(r'\s{2,}')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Name: Country, Length: 89, dtype: bool

# %%
df['Country'].str.upper()
# Out:
# 0      UNITED STATES
# 1     UNITED KINGDOM
# 2      UNITED STATES
# 3          AUSTRALIA
# 4     UNITED  STATES
#            ...
# 84           GERMANY
# 85     UNITED STATES
# 86            CANADA
# 87     UNITED STATES
# 88         AUSTRALIA
# Name: Country, Length: 89, dtype: object

# %%
df.isnull().sum()
# Out:
# Sales_Order #          0
# Date                   0
# Day                    1
# Month                  0
# Year                   0
# Customer_Age           0
# Age_Group              1
# Customer_Gender        0
# Country                0
# State                  0
# Product_Category       0
# Sub_Category           0
# Product_Description    1
# Order_Quantity         1
#  Unit_Cost             0
#  Unit_Price            0
#  Profit                0
#  Cost                  0
# Revenue                0
# dtype: int64

# %%
df
# Out:
#     Sales_Order #        Date   Day     Month  Year  Customer_Age  \
# 0          261695  2021-12-01   1.0  December  2021            39
# 1          261695  2021-12-01   1.0  December  2021            44
# 2          261697  2021-12-02   2.0  December  2021            37
# 3          261698  2021-12-02   2.0  December  2021            31
# 4          261699  2021-12-03   3.0  December  2021            37
# ..            ...         ...   ...       ...   ...           ...
# 84         261778  2021-12-22  22.0  December  2021            41
# 85         261779  2021-12-23  23.0  December  2021            30
# 86         261780  2021-12-23  23.0  December  2021            31
# 87         261781  2021-12-23  23.0  December  2021            35
# 88         261782  2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
df.columns
# Out:
# Index(['Sales_Order #', 'Date', 'Day', 'Month', 'Year', 'Customer_Age',
#        'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product_Description', 'Order_Quantity', ' Unit_Cost ',
#        ' Unit_Price ', ' Profit ', ' Cost ', 'Revenue'],
#       dtype='object')

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
# ...

# %%
# !pip install --upgrade numba

# %%
# !pip uninstall visions
# !pip install visions==0.7.0
# Out:
# ^C
# ^C
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.0 which is incompatible.
# ...
#   Attempting uninstall: multimethod
#     Found existing installation: multimethod 1.12
#     Uninstalling multimethod-1.12:
#       Successfully uninstalled multimethod-1.12
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# ...

# %%
# !pip install sweetviz
# Out:
# ...
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    --------- ------------------------------ 3.7/15.1 MB 18.2 MB/s eta 0:00:01
#    ------------------- -------------------- 7.3/15.1 MB 17.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.0/15.1 MB 17.2 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/15.1 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 15.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import sweetviz as sv

# Load your dataset (for example, a CSV file)
df = pd.read_csv('Bike_Sales_Prepare_Lab_3.4.7.xlsx')

# Create the report
report = sv.analyze(df)

# Save the report as an HTML file
report.show_html('sweetviz_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
import pandas_profiling

# Example usage
from pandas_profiling import ProfileReport
df = pd.read_csv('Bike_Sales_Prepare_Lab_3.4.7.xlsx.csv')  # Load your DataFrame
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("your_report.html")  # Save the report to an HTML file
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 import pandas_profiling
#       3 # Example usage
#       4 from pandas_profiling import ProfileReport
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
# ...
